# %% [markdown]
# ## Imports

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import h5py

# %% [markdown]
# ## Read in file

# %%
file = "snapshot_150_O1_dust_rho_xy.fits"
with fits.open(file) as hdul:
    dust_density = hdul[0].data
    header = hdul[0].header

#print(header)

# %% [markdown]
# ## Conversions

# %%
# going from msun/au^3 to g/cm^3
msun_to_g = u.Msun.to('g')
au_to_cm = u.AU.to('cm')
conv_factor = msun_to_g / (au_to_cm)**3
dust_density_cgs = dust_density * conv_factor

# %% [markdown]
# ## Density Plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
# msun/au^3
im1 = axes[0].imshow(np.log10(dust_density), cmap='viridis', origin='lower')
cbar1 = fig.colorbar(im1, ax=axes[0], label=r'$\log_{10}(\rho_{\rm dust})$ [Msun/AU$^3$]')
axes[0].set_xlabel('X [pc]')
axes[0].set_ylabel('Y [pc]')
axes[0].set_title('Dust Density Projection (XY Plane)')
axes[0].set_xlim(490, 530)
axes[0].set_ylim(490, 530)
# g/cm^3
im2 = axes[1].imshow(np.log10(dust_density_cgs), cmap='viridis', origin='lower')
cbar2 = fig.colorbar(im2, ax=axes[1], label=r'$\log_{10}(\rho_{\rm dust})$ [g/cm$^3$]')
axes[1].set_xlabel('X [pc]')
axes[1].set_ylabel('Y [pc]')
axes[1].set_title('Dust Density Projection (XY Plane)')
axes[1].set_xlim(490, 530)
axes[1].set_ylim(490, 530)

plt.tight_layout()
plt.savefig('dust_density_xy_dual_units_log.png', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_632/1752916435.py:3: RuntimeWarning: divide by zero encountered in log10
#   im1 = axes[0].imshow(np.log10(dust_density), cmap='viridis', origin='lower')
# /tmp/ipykernel_632/1752916435.py:11: RuntimeWarning: divide by zero encountered in log10
#   im2 = axes[1].imshow(np.log10(dust_density_cgs), cmap='viridis', origin='lower')

# %% [markdown]
# ## Histogram

# %%
flat_density = dust_density.flatten()
flat_dust = flat_density[flat_density > 0]
flat_dust_cgs = flat_dust * conv_factor

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# msun/au^3
axes[0].hist(np.log10(flat_dust), bins=50)
axes[0].set_xlabel(r'$\log_{10}(\rho_{\rm dust})$ [Msun/AU$^3$]')
axes[0].set_ylabel('Count')
axes[0].set_title('Dust Density (Log Scale)')
axes[0].grid()

# g/cm^3
axes[1].hist(np.log10(flat_dust_cgs), bins=50)
axes[1].set_xlabel(r'$\log_{10}(\rho_{\rm dust})$ [g/cm$^3$]')
axes[1].set_ylabel('Count')
axes[1].set_title('Dust Density (Log Scale)')
axes[1].grid()

plt.tight_layout()
plt.savefig('dust_density_histogram_dual_units_log.png', dpi=300)
plt.show()

# %% [markdown]
# ## Overplotting stars on dust density plots

# %% [markdown]
# ### Loading in the snapshot file

# %%
# getting the star coords
snap_file = 'snapshot_150.hdf5'
with h5py.File(snap_file, 'r') as f:
    star_coords = f['PartType5']['Coordinates'][:]

# %%
# --- Get the extent of the dust density plot---
# You might need to adjust these based on how the FITS file was created and its header
try:
    xmin = header['CRVAL1'] - header['CDELT1'] * (header['NAXIS1'] / 2)
    xmax = header['CRVAL1'] + header['CDELT1'] * (header['NAXIS1'] / 2)
    ymin = header['CRVAL2'] - header['CDELT2'] * (header['NAXIS2'] / 2)
    ymax = header['CRVAL2'] + header['CDELT2'] * (header['NAXIS2'] / 2)
except KeyError:
    # If header doesn't have these keywords, you might need to estimate or know the extent
    print("Warning: Could not determine spatial extent from FITS header. You might need to set xlim and ylim manually.")
    xmin, xmax = 490, 530  # Using your previous limits as a fallback
    ymin, ymax = 490, 530

# --- Project star coordinates onto the XY plane ---
star_x = star_coords[:, 0]
star_y = star_coords[:, 1]

# --- Create the dust density plot with stars overplotted ---
plt.figure(figsize=(10, 8))
plt.imshow(np.log10(dust_density), cmap='viridis', origin='lower', extent=[xmin, xmax, ymin, ymax])
plt.colorbar(label=r'$\log_{10}(\rho_{\rm dust})$ [Msun/AU$^3$]')
plt.scatter(star_x, star_y, s=10, color='white', marker='*', label='Stars', alpha=0.7) # Overplot stars
plt.xlabel('X [pc]')
plt.ylabel('Y [pc]')
plt.title('Dust Density with Overplotted Stars (XY Plane)')
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
plt.legend()
plt.tight_layout()
plt.savefig('dust_density_with_stars_xy_log.png', dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_632/3001997009.py:20: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(dust_density), cmap='viridis', origin='lower', extent=[xmin, xmax, ymin, ymax])
